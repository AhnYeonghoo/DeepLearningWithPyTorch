# %%
import pandas as pd
import numpy as np

train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 8))
train['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title("Survived")
ax[0].set_ylabel('')
sns.countplot(x='Survived', data=train, ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.violinplot(x="Pclass", y="Age", hue="Survived", data=train, split=True, ax=ax[0])
ax[0].set_title("Pclass&Age")
ax[0].set_yticks(range(0, 110, 10))
sns.violinplot(x="Sex", y="Age", hue="Survived", data=train, split=True, ax=ax[1])
ax[1].set_title("Sex & Age")
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %%
train["Initial"] = 0
for i in train:
    train["Initial"] = train['Name'].str.extract('([a-zA-Z]+)\.')

# %%
pd.crosstab(train['Initial'], train['Sex']).T.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_38d85_row0_col0, #T_38d85_row0_col1, #T_38d85_row0_col3, #T_38d85_row0_col4, #T_38d85_row0_col5, #T_38d85_row0_col7, #T_38d85_row0_col8, #T_38d85_row0_col12, #T_38d85_row0_col15, #T_38d85_row0_col16, #T_38d85_row1_col2, #T_38d85_row1_col6, #T_38d85_row1_col9, #T_38d85_row1_col10, #T_38d85_row1_col11, #T_38d85_row1_col13, #T_38d85_row1_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_38d85_row0_col2, #T_38d85_row0_col6, #T_38d85_row0_col9, #T_38d85_row0_col10, #T_38d85_row0_col11, #T_38d85_row0_col13, #T_38d85_row0_col14, #T_38d85_row1_col0, #T_38d85_row1_col1, #T_38d85_row1_col3, #T_38d85_row1_col4, #T_38d85_row1_col5, #T_38d85_row1_col7, #T_38d85_row1_col8, #T_38d85_row1_col12, #T_38d85_row1_col15, #T_38d85_row1_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_38d85">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_38d85_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_38d85_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_38d85_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_38d85_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_38d85_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_38d85_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_38d85_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_38d85_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_38d85_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_38d85_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_38d85_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_38d85_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_38d85_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_38d85_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_38d85_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_38d85_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_38d85_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38d85_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_38d85_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_38d85_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_38d85_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_38d85_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_38d85_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_38d85_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_38d85_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_38d85_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_38d85_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_38d85_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_38d85_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_38d85_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_38d85_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_38d85_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_38d85_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_38d85_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_38d85_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_38d85_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_38d85_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_38d85_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_38d85_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_38d85_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_38d85_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_38d85_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_38d85_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_38d85_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_38d85_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_38d85_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_38d85_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_38d85_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_38d85_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_38d85_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_38d85_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_38d85_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_38d85_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
train.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Capt        70.000000
# Col         58.000000
# Countess    33.000000
# Don         40.000000
# Dr          42.000000
# Jonkheer    38.000000
# Lady        48.000000
# Major       48.500000
# Master       4.574167
# Miss        21.773973
# Mlle        24.000000
# Mme         24.000000
# Mr          32.368090
# Mrs         35.898148
# Ms          28.000000
# Rev         43.166667
# Sir         49.000000
# Name: Age, dtype: float64
